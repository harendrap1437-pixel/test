# %% [markdown]
# # 🚀 AI Portable Language Translator - 24/7 Cloud Host
# Run your full AI translation backend and live public website directly on Google's cloud servers (Free 12GB+ RAM & GPU).

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Navigate to your uploaded project folder
# %cd /content/drive/MyDrive/ai speec reco

# 3. Install required packages
# !pip install -q fastapi uvicorn python-multipart onnxruntime soundfile numpy scipy ctranslate2 transformers sentencepiece sherpa_onnx psutil

# 4. Install Cloudflare tunnel
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /usr/local/bin/cloudflared
# !chmod +x /usr/local/bin/cloudflared

# 5. Start Backend Server & Expose Public URL
import subprocess, time
subprocess.Popen(["python3", "-m", "uvicorn", "backend.app:app", "--host", "0.0.0.0", "--port", "8000"])
time.sleep(4)

# Run Cloudflare Tunnel (Your live HTTPS link will appear below)
# !cloudflared tunnel --url http://127.0.0.1:8000
